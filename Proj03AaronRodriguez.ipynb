# %% [markdown]
# ### Table of Contents

# %% [markdown]
# * [Certification](#certification)
# * [Import libraries](#import-libraries)
# * [Perform computations](#perform-computation)
# * [Display the figure](#display-the-figure)

# %% [markdown]
# ### Certification <a class="anchor" id="certification"></a>

# %% [markdown]
# I certify that this project is my own work and is not the work of others. I agree not to share my solution with others. -Aaron Rodriguez

# %% [markdown]
# ### Import Libraries <a class="anchor" id="import-libraries"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib
# %matplotlib notebook

def ioff():
    matplotlib.interactive(False)
    plt.uninstall_repl_displayhook()

ioff()

# %% [markdown]
# ### Perform computations <a class="anchor" id="perform-computation"></a>

# %%
t = np.arange(0, 6.0, 0.05)
plt.plot(t, np.exp(t) * np.sin(2*np.pi*t))
print(plt.gcf()) #Get a reference to the current figure
# Out:
# Figure(432x288)

# %% [markdown]
# ### Display the figure <a class="anchor" id="display-the-figure"></a>

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="475.45453514934593">

# %%
## The End ##
