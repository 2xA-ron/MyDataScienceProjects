# %% [markdown]
# ### Table of contents

# %% [markdown]
# * [Certifacation](#certification)
# * [Display figure](#display-figure)
#      * [Import libraries](#import-libraries)
#      * [Perform computations](#perform-computations)

# %% [markdown]
# ### Certification <a class="anchor" id="certification"></a>

# %% [markdown]
# I certify that this project is my own work and is not the work of others. I agree not to share my solution with others. -Aaron Rodriguez

# %% [markdown]
# ### Display figure <a class="anchor" id="display-figure"></a>

# %% [markdown]
# ### Import libraries <a class="anchor" id="import-libraries"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook

# %% [markdown]
# ### Perform computations  <a class="anchor" id="perform-computations"></a>

# %%
t = np.arange(0, 6.0, 0.05)
plt.plot(t, np.exp(t) * np.sin(2*np.pi*t))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
##The End##
